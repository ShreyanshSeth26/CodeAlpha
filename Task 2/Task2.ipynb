# %%
import os
import warnings
import time
import random
import shutil
import joblib
import numpy as np
import librosa
import logging
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from keras.models import Sequential, load_model
from keras.layers import Conv1D, Activation, Dropout, Flatten, Dense
from keras.utils import plot_model as KerasPlotModel
from absl import logging as absl_logging

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')
absl_logging.set_verbosity(absl_logging.ERROR)
logging.getLogger('tensorflow').setLevel(logging.ERROR)

TrainingDataDirectory = r"X:\Projects\CodeAlpha\Task 2\features"
FeatureStorageDirectory = r"X:\Projects\CodeAlpha\Task 2\joblib_features"
ModelOutputDirectory = r"X:\Projects\CodeAlpha\Task 2\model"
TessSourceDirectory = r"X:\Projects\CodeAlpha\Task 2\TESS"
ExampleAudioDirectory = r"X:\Projects\CodeAlpha\Task 2\examples"

EmotionLabels = {
    0: 'neutral', 1: 'calm', 2: 'happy', 3: 'sad',
    4: 'angry', 5: 'fearful', 6: 'disgust', 7: 'surprised'
}

# %%
def PrepareTessAudioDirectories(sourceDir, destDir=TrainingDataDirectory):
    print(f"[TESS] Preparing WAV files from {sourceDir}")
    mappingCodes = {'01':'neutral','03':'happy','04':'sad','05':'angry','06':'fear','07':'disgust','08':'ps'}
    for basePath, _, files in os.walk(sourceDir):
        for fileName in files:
            if not fileName.endswith('.wav'): continue
            actorFolder = 'Actor_26' if fileName.startswith('OAF') else 'Actor_25'
            targetDir = os.path.join(destDir, actorFolder)
            os.makedirs(targetDir, exist_ok=True)
            nameRoot, ext = os.path.splitext(fileName)
            for code, label in mappingCodes.items():
                if nameRoot.endswith(label):
                    randomId = random.sample(range(10,99), 7)
                    newName = '-'.join(map(str, randomId))
                    finalName = newName[:6] + code + newName[8:] + ext
                    shutil.copy(os.path.join(basePath, fileName), os.path.join(targetDir, finalName))
    print("[TESS] Audio directories populated")

# %%
def ExtractMfccFromAudio(sourceDir=TrainingDataDirectory, outputDir=FeatureStorageDirectory):
    print(f"[Features] Extracting MFCCs from {sourceDir}")
    featureList = []
    startTime = time.time()
    for rootPath, _, files in os.walk(sourceDir):
        for audioFile in files:
            if not audioFile.endswith('.wav'): continue
            filePath = os.path.join(rootPath, audioFile)
            try:
                data, sr = librosa.load(filePath, sr=None)
                mfccVector = np.mean(librosa.feature.mfcc(y=data, sr=sr, n_mfcc=40).T, axis=0)
                labelIndex = int(audioFile[7:8]) - 1
                featureList.append((mfccVector, labelIndex))
            except Exception as error:
                print(f"[Features] Error processing {audioFile}: {error}")
    duration = time.time() - startTime
    print(f"[Features] Extracted {len(featureList)} MFCCs in {duration:.2f}s")
    features, labels = zip(*featureList)
    features = np.array(features)
    labels = np.array(labels)
    os.makedirs(outputDir, exist_ok=True)
    joblib.dump(features, os.path.join(outputDir, 'X.joblib'))
    joblib.dump(labels, os.path.join(outputDir, 'y.joblib'))
    print(f"[Features] Features saved to {outputDir}")

# %%
def TrainConv1DEmotionModel(featuresDir=FeatureStorageDirectory, modelDir=ModelOutputDirectory):
    print(f"[Training] Loading data from {featuresDir}")
    X = joblib.load(os.path.join(featuresDir, 'X.joblib'))
    y = joblib.load(os.path.join(featuresDir, 'y.joblib'))
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    X_train_expanded = X_train[..., np.newaxis]
    X_test_expanded = X_test[..., np.newaxis]
    print("[Training] Building Conv1D network")
    model = Sequential([
        Conv1D(64, 5, padding='same', input_shape=(40,1)),
        Activation('relu'),
        Dropout(0.2),
        Flatten(),
        Dense(8),
        Activation('softmax')
    ])
    model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    print("[Training] Starting training")
    history = model.fit(X_train_expanded, y_train, batch_size=16, epochs=50, validation_data=(X_test_expanded, y_test))
    os.makedirs(modelDir, exist_ok=True)
    print("[Training] Saving performance charts")
    plt.figure()
    plt.plot(history.history['loss'], label='TrainLoss')
    plt.plot(history.history['val_loss'], label='ValLoss')
    plt.legend()
    plt.savefig(os.path.join(modelDir, 'LossChart.png'))
    plt.close()
    plt.figure()
    plt.plot(history.history['accuracy'], label='TrainAcc')
    plt.plot(history.history['val_accuracy'], label='ValAcc')
    plt.legend()
    plt.savefig(os.path.join(modelDir, 'AccuracyChart.png'))
    plt.close()
    print("[Training] Generating evaluation report")
    preds = np.argmax(model.predict(X_test_expanded), axis=1)
    print(classification_report(y_test, preds))
    print(confusion_matrix(y_test, preds))
    modelPath = os.path.join(modelDir, 'EmotionDetectionModel.h5')
    model.save(modelPath)
    print(f"[Training] Model saved to {modelPath}")

# %%
def GenerateModelDiagram(modelDir=ModelOutputDirectory):
    print("[Plot] Visualizing model architecture")
    trainedModel = load_model(os.path.join(modelDir, 'EmotionDetectionModel.h5'))
    KerasPlotModel(trainedModel, to_file=os.path.join(modelDir, 'ModelDiagram.png'), show_shapes=True)
    print("[Plot] Model diagram created")

# %%
def RunPredictionsOnExamples(examplesDir=ExampleAudioDirectory, modelDir=ModelOutputDirectory):
    if not os.path.isdir(examplesDir):
        print(f"[Predict] No examples in {examplesDir}")
        return
    print(f"[Predict] Classifying examples in {examplesDir}")
    model = load_model(os.path.join(modelDir, 'EmotionDetectionModel.h5'))
    for fileName in os.listdir(examplesDir):
        if not fileName.endswith('.wav'): continue
        filePath = os.path.join(examplesDir, fileName)
        data, sr = librosa.load(filePath, sr=None)
        mfccVec = np.mean(librosa.feature.mfcc(y=data, sr=sr, n_mfcc=40).T, axis=0)
        index = np.argmax(model.predict(mfccVec[np.newaxis,...,np.newaxis]))
        print(f"[Predict] {fileName} => {EmotionLabels.get(index,'Unknown')}")

# %%
print("[Pipeline] Running full emotion detection pipeline")
PrepareTessAudioDirectories(TessSourceDirectory)
ExtractMfccFromAudio()
TrainConv1DEmotionModel()
GenerateModelDiagram()
# Out:
# [Pipeline] Running full emotion detection pipeline
# [TESS] Preparing WAV files from X:\Projects\CodeAlpha\Task 2\TESS
# [TESS] Audio directories populated
# [Features] Extracting MFCCs from X:\Projects\CodeAlpha\Task 2\features
# [Features] Extracted 5252 MFCCs in 39.88s
# [Features] Features saved to X:\Projects\CodeAlpha\Task 2\joblib_features
# [Training] Loading data from X:\Projects\CodeAlpha\Task 2\joblib_features
# [Training] Building Conv1D network
# [Training] Starting training
# Epoch 1/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3589 - loss: 5.9117 - val_accuracy: 0.5185 - val_loss: 2.3107
# Epoch 2/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5817 - loss: 2.0285 - val_accuracy: 0.6494 - val_loss: 1.1063
# Epoch 3/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6836 - loss: 1.0772 - val_accuracy: 0.6840 - val_loss: 0.8826
# Epoch 4/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7239 - loss: 0.7803 - val_accuracy: 0.7024 - val_loss: 0.8477
# Epoch 5/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.7119 - val_accuracy: 0.7693 - val_loss: 0.6682
# Epoch 6/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7697 - loss: 0.6594 - val_accuracy: 0.7445 - val_loss: 0.7423
# Epoch 7/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7678 - loss: 0.6624 - val_accuracy: 0.7589 - val_loss: 0.6475
# Epoch 8/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7856 - loss: 0.6090 - val_accuracy: 0.7457 - val_loss: 0.7043
# Epoch 9/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7813 - loss: 0.6145 - val_accuracy: 0.7653 - val_loss: 0.6601
# Epoch 10/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8070 - loss: 0.5692 - val_accuracy: 0.7509 - val_loss: 0.7616
# Epoch 11/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7944 - loss: 0.5735 - val_accuracy: 0.7757 - val_loss: 0.6281
# Epoch 12/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.5789 - val_accuracy: 0.7699 - val_loss: 0.6505
# Epoch 13/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8034 - loss: 0.5372 - val_accuracy: 0.7734 - val_loss: 0.6509
# Epoch 14/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.5657 - val_accuracy: 0.7584 - val_loss: 0.6927
# Epoch 15/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8063 - loss: 0.5383 - val_accuracy: 0.7803 - val_loss: 0.6141
# Epoch 16/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8168 - loss: 0.5125 - val_accuracy: 0.7924 - val_loss: 0.5977
# Epoch 17/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8093 - loss: 0.5334 - val_accuracy: 0.7878 - val_loss: 0.6055
# Epoch 18/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8283 - loss: 0.4863 - val_accuracy: 0.7878 - val_loss: 0.6012
# Epoch 19/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8184 - loss: 0.5157 - val_accuracy: 0.7901 - val_loss: 0.6032
# Epoch 20/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8268 - loss: 0.4968 - val_accuracy: 0.7809 - val_loss: 0.6392
# Epoch 21/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8134 - loss: 0.5157 - val_accuracy: 0.8039 - val_loss: 0.5845
# Epoch 22/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.5147 - val_accuracy: 0.7930 - val_loss: 0.6145
# Epoch 23/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8357 - loss: 0.4681 - val_accuracy: 0.7872 - val_loss: 0.6321
# Epoch 24/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8386 - loss: 0.4600 - val_accuracy: 0.8097 - val_loss: 0.5651
# Epoch 25/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8413 - loss: 0.4564 - val_accuracy: 0.7780 - val_loss: 0.6466
# Epoch 26/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8177 - loss: 0.4829 - val_accuracy: 0.8016 - val_loss: 0.5742
# Epoch 27/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8313 - loss: 0.4681 - val_accuracy: 0.7970 - val_loss: 0.6096
# Epoch 28/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.4412 - val_accuracy: 0.7739 - val_loss: 0.6654
# Epoch 29/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8382 - loss: 0.4472 - val_accuracy: 0.7953 - val_loss: 0.5938
# Epoch 30/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8567 - loss: 0.4207 - val_accuracy: 0.7699 - val_loss: 0.6981
# Epoch 31/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.4504 - val_accuracy: 0.7964 - val_loss: 0.6417
# Epoch 32/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.4581 - val_accuracy: 0.7970 - val_loss: 0.6033
# Epoch 33/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8406 - loss: 0.4688 - val_accuracy: 0.7716 - val_loss: 0.6566
# Epoch 34/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8489 - loss: 0.4256 - val_accuracy: 0.8057 - val_loss: 0.5962
# Epoch 35/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8376 - loss: 0.4455 - val_accuracy: 0.7849 - val_loss: 0.6909
# Epoch 36/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8455 - loss: 0.4214 - val_accuracy: 0.8068 - val_loss: 0.5640
# Epoch 37/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8493 - loss: 0.4289 - val_accuracy: 0.7935 - val_loss: 0.6383
# Epoch 38/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.4286 - val_accuracy: 0.8016 - val_loss: 0.6321
# Epoch 39/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.4120 - val_accuracy: 0.7872 - val_loss: 0.6565
# Epoch 40/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8556 - loss: 0.4263 - val_accuracy: 0.8005 - val_loss: 0.6007
# Epoch 41/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8537 - loss: 0.4129 - val_accuracy: 0.7982 - val_loss: 0.6165
# Epoch 42/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8676 - loss: 0.3786 - val_accuracy: 0.8085 - val_loss: 0.6029
# Epoch 43/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8538 - loss: 0.4367 - val_accuracy: 0.8062 - val_loss: 0.6082
# Epoch 44/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.3878 - val_accuracy: 0.8097 - val_loss: 0.6081
# Epoch 45/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8608 - loss: 0.4181 - val_accuracy: 0.8033 - val_loss: 0.6283
# Epoch 46/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8594 - loss: 0.4091 - val_accuracy: 0.7855 - val_loss: 0.7132
# Epoch 47/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3823 - val_accuracy: 0.8097 - val_loss: 0.6091
# Epoch 48/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.3842 - val_accuracy: 0.7832 - val_loss: 0.7168
# Epoch 49/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.3953 - val_accuracy: 0.7999 - val_loss: 0.6672
# Epoch 50/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.4207 - val_accuracy: 0.8062 - val_loss: 0.6072
# [Training] Saving performance charts
# [Training] Generating evaluation report
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       196
#            1       0.63      0.74      0.68       123
#            2       0.87      0.74      0.80       247
#            3       0.79      0.85      0.82       267
#            4       0.76      0.90      0.83       263
#            5       0.93      0.71      0.81       237
#            6       0.75      0.85      0.80       201
#            7       0.88      0.76      0.81       200
#
#     accuracy                           0.81      1734
#    macro avg       0.81      0.80      0.80      1734
# weighted avg       0.82      0.81      0.81      1734
#
# [[169  13   0   9   0   0   4   1]
#  [  8  91   1  11   1   2   8   1]
#  [  3  20 184   2  21   3   8   6]
#  [  3  10   5 227  13   4   4   1]
#  [  5   1   5   6 236   1   6   3]
#  [  6   4   9  22  19 169   2   6]
#  [  3   4   2   5  11   3 171   2]
#  [  3   1   6   6   8   0  25 151]]
# [Training] Model saved to X:\Projects\CodeAlpha\Task 2\model\EmotionDetectionModel.h5
# [Plot] Visualizing model architecture
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# [Plot] Model diagram created

# %%
RunPredictionsOnExamples()
# Out:
# [Predict] Classifying examples in X:\Projects\CodeAlpha\Task 2\examples
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [Predict] 03-01-01-01-01-02-05.wav => neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [Predict] 10-16-07-29-82-30-63.wav => disgust
